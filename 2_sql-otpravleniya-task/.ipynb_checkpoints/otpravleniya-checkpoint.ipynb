# %% [markdown]
# # Tasks:
# 1. Вывести средний размер тарифа на пересылку и массы по индексам отделений, в которых было принято отправление.
# 2. Вывести количество отправлений в разрезе индексов отделений, в которых было принято отправление. Учитывать только те отправления, у которых масса  больше  или равна 10 кг.
# 3. Вывести  количество отправлений в разрезе  типа отправителя и группы по численности населения населенного пункта, в котором было принято отправление (меньше 50 тыс. (включительно), от 50 до 100 тыс. (включительно), от 100 до 500 тыс. (включительно), больше 500 тыс.).
# 4. Вывести идентификатор отправления; регион, где было принято отправление; численность населения населенного пункта, в котором было принято отправление и стоимость пересылки отправления (в рублях) с максимальной массой в каждом филиале.
# 5. Вывести идентификаторы отправлений, у которых  масса строго больше, чем в среднем по базе. Перед отпуском руководитель попросил вас: «вывести распределение количества отправлений по стоимости пересылки*». Необходимо подготовить 1 слайд, который раскроет данную проблематику.
# *Подсказка: задание творческое.  При выполнении задания можно создавать промежуточные таблицы - приложить код и описать графики, которые будут показаны на слайде.

# %% [markdown]
# # 0. Генерим данные

# %%
import sqlite3
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
sqlite3.sqlite_version
# Out:
# '3.40.1'

# %%
def select(sql):
  return pd.read_sql(sql,con)

# %%
parcel_aggr = pd.DataFrame({'parcel_id':range(100)})

# %%
parcel_aggr
# Out:
#     parcel_id
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
# ..        ...
# 95         95
# 96         96
# 97         97
# 98         98
# 99         99
#
# [100 rows x 1 columns]

# %%
parcel_aggr['accept_date'] = (pd.Series(pd.date_range(start='2017-04-01',end='2017-04-30'))
    .sample(100,replace=True,random_state=42)
    .values)

# %%
parcel_aggr
# Out:
#     parcel_id accept_date
# 0           0  2017-04-07
# 1           1  2017-04-20
# 2           2  2017-04-29
# 3           3  2017-04-15
# 4           4  2017-04-11
# ..        ...         ...
# 95         95  2017-04-29
# 96         96  2017-04-18
# 97         97  2017-04-26
# 98         98  2017-04-12
# 99         99  2017-04-02
#
# [100 rows x 2 columns]

# %%
parcel_aggr['index_id'] = pd.Series(range(10)).sample(100,replace=True,random_state=42).values

# %%
parcel_aggr
# Out:
#     parcel_id accept_date  index_id
# 0           0  2017-04-07         6
# 1           1  2017-04-20         3
# 2           2  2017-04-29         7
# 3           3  2017-04-15         4
# 4           4  2017-04-11         6
# ..        ...         ...       ...
# 95         95  2017-04-29         9
# 96         96  2017-04-18         8
# 97         97  2017-04-26         6
# 98         98  2017-04-12         8
# 99         99  2017-04-02         7
#
# [100 rows x 3 columns]

# %%
np.random.seed(42)
pd.Series(np.random.normal(1000,2000,size=100)).hist()
# Out:
# <AxesSubplot: >

# %%
np.random.seed(42)
pd.Series(np.abs(np.random.normal(1000,2000,size=100))).hist()
# Out:
# <AxesSubplot: >

# %%
np.random.seed(42)
parcel_aggr['mass'] = np.round(np.abs(np.random.normal(10000,20000,size=100))).astype(int)

# %%
parcel_aggr
# Out:
#     parcel_id accept_date  index_id   mass
# 0           0  2017-04-07         6  19934
# 1           1  2017-04-20         3   7235
# 2           2  2017-04-29         7  22954
# 3           3  2017-04-15         4  40461
# 4           4  2017-04-11         6   5317
# ..        ...         ...       ...    ...
# 95         95  2017-04-29         9  19270
# 96         96  2017-04-18         8  15922
# 97         97  2017-04-26         6  15221
# 98         98  2017-04-12         8  10102
# 99         99  2017-04-02         7   5308
#
# [100 rows x 4 columns]

# %%
np.random.seed(42)
parcel_aggr['price'] = np.round(np.abs(np.random.normal(10000,40000,size=100))).astype(int)

# %%
parcel_aggr
# Out:
#     parcel_id accept_date  index_id   mass  price
# 0           0  2017-04-07         6  19934  29869
# 1           1  2017-04-20         3   7235   4469
# 2           2  2017-04-29         7  22954  35908
# 3           3  2017-04-15         4  40461  70921
# 4           4  2017-04-11         6   5317    634
# ..        ...         ...       ...    ...    ...
# 95         95  2017-04-29         9  19270  48541
# 96         96  2017-04-18         8  15922  21845
# 97         97  2017-04-26         6  15221  20442
# 98         98  2017-04-12         8  10102  10205
# 99         99  2017-04-02         7   5308    617
#
# [100 rows x 5 columns]

# %%
parcel_aggr['client_type'] = (pd.Series(['Физическое лицо','Юридическое лицо'])
.sample(100,replace=True,random_state=42).values)

# %%
parcel_aggr
# Out:
#     parcel_id accept_date  index_id   mass  price       client_type
# 0           0  2017-04-07         6  19934  29869   Физическое лицо
# 1           1  2017-04-20         3   7235   4469  Юридическое лицо
# 2           2  2017-04-29         7  22954  35908   Физическое лицо
# 3           3  2017-04-15         4  40461  70921   Физическое лицо
# 4           4  2017-04-11         6   5317    634   Физическое лицо
# ..        ...         ...       ...    ...    ...               ...
# 95         95  2017-04-29         9  19270  48541  Юридическое лицо
# 96         96  2017-04-18         8  15922  21845  Юридическое лицо
# 97         97  2017-04-26         6  15221  20442  Юридическое лицо
# 98         98  2017-04-12         8  10102  10205  Юридическое лицо
# 99         99  2017-04-02         7   5308    617   Физическое лицо
#
# [100 rows x 6 columns]

# %%
parcel_aggr['index_id'].value_counts()
# Out:
# 7    15
# 8    12
# 6    11
# 9    11
# 4    10
# 1    10
# 3     9
# 2     9
# 0     7
# 5     6
# Name: index_id, dtype: int64

# %%
parcel_aggr['index_id'].unique()
# Out:
# array([6, 3, 7, 4, 9, 2, 5, 1, 0, 8])

# %%
index_data = pd.DataFrame({'index_id':range(10)})

# %%
index_data['area'] = ['a','b','c','d','e','f','g','h','i','j']

# %%
np.random.seed(42)
index_data['population'] = np.round(np.abs(np.random.normal(10000,40000,size=10))).astype(int)

# %%
index_data['population'] = [10000,20002,60000,70000,100001,150000,200000,300000,600000,700000]

# %%
index_data
# Out:
#    index_id area  population
# 0         0    a       10000
# 1         1    b       20002
# 2         2    c       60000
# 3         3    d       70000
# 4         4    e      100001
# 5         5    f      150000
# 6         6    g      200000
# 7         7    h      300000
# 8         8    i      600000
# 9         9    j      700000

# %%
con = sqlite3.connect('db')
cur = con.cursor()

# %%
parcel_aggr.to_sql('parcel_aggr',con,if_exists='replace',index=False)
# Out:
# 100

# %%
sql = '''
select *
from parcel_aggr t
'''

# %%
select(sql)
# Out:
#     parcel_id          accept_date  index_id   mass  price       client_type
# 0           0  2017-04-07 00:00:00         6  19934  29869   Физическое лицо
# 1           1  2017-04-20 00:00:00         3   7235   4469  Юридическое лицо
# 2           2  2017-04-29 00:00:00         7  22954  35908   Физическое лицо
# 3           3  2017-04-15 00:00:00         4  40461  70921   Физическое лицо
# 4           4  2017-04-11 00:00:00         6   5317    634   Физическое лицо
# ..        ...                  ...       ...    ...    ...               ...
# 95         95  2017-04-29 00:00:00         9  19270  48541  Юридическое лицо
# 96         96  2017-04-18 00:00:00         8  15922  21845  Юридическое лицо
# 97         97  2017-04-26 00:00:00         6  15221  20442  Юридическое лицо
# 98         98  2017-04-12 00:00:00         8  10102  10205  Юридическое лицо
# 99         99  2017-04-02 00:00:00         7   5308    617   Физическое лицо
#
# [100 rows x 6 columns]

# %%
index_data.to_sql('index_data',con,if_exists='replace',index=False)
# Out:
# 10

# %%
sql = '''
select *
from index_data t
'''

# %%
select(sql)
# Out:
#    index_id area  population
# 0         0    a       10000
# 1         1    b       20002
# 2         2    c       60000
# 3         3    d       70000
# 4         4    e      100001
# 5         5    f      150000
# 6         6    g      200000
# 7         7    h      300000
# 8         8    i      600000
# 9         9    j      700000

# %% [markdown]
# # Analysis

# %%
sql = '''
select * 
from parcel_aggr t
'''

# %%
select(sql)
# Out:
#     parcel_id          accept_date  index_id   mass  price       client_type
# 0           0  2017-04-07 00:00:00         6  19934  29869   Физическое лицо
# 1           1  2017-04-20 00:00:00         3   7235   4469  Юридическое лицо
# 2           2  2017-04-29 00:00:00         7  22954  35908   Физическое лицо
# 3           3  2017-04-15 00:00:00         4  40461  70921   Физическое лицо
# 4           4  2017-04-11 00:00:00         6   5317    634   Физическое лицо
# ..        ...                  ...       ...    ...    ...               ...
# 95         95  2017-04-29 00:00:00         9  19270  48541  Юридическое лицо
# 96         96  2017-04-18 00:00:00         8  15922  21845  Юридическое лицо
# 97         97  2017-04-26 00:00:00         6  15221  20442  Юридическое лицо
# 98         98  2017-04-12 00:00:00         8  10102  10205  Юридическое лицо
# 99         99  2017-04-02 00:00:00         7   5308    617   Физическое лицо
#
# [100 rows x 6 columns]

# %%
sql = '''
select * 
from index_data t
'''

# %%
select(sql)
# Out:
#    index_id area  population
# 0         0    a       10000
# 1         1    b       20002
# 2         2    c       60000
# 3         3    d       70000
# 4         4    e      100001
# 5         5    f      150000
# 6         6    g      200000
# 7         7    h      300000
# 8         8    i      600000
# 9         9    j      700000

# %% [markdown]
# ## 1. Вывести средний размер тарифа на пересылку и массы по индексам отделений, в которых было принято отправление.

# %%
sql = '''
select t.index_id,
    count(t.index_id) AS cnt,
    avg(t.price) AS price_avg,
    avg(t.mass) AS mass_avg
    
from parcel_aggr as t
group by t.index_id
'''

# %%
select(sql)
# Out:
#    index_id  cnt     price_avg      mass_avg
# 0         0    7  16729.428571  11164.000000
# 1         1   10  28877.000000  13596.000000
# 2         2    9  43902.222222  24729.000000
# 3         3    9  18383.111111  10928.111111
# 4         4   10  41301.800000  21651.000000
# 5         5    6  26750.166667  12980.166667
# 6         6   11  24733.090909  15031.636364
# 7         7   15  32669.733333  16841.000000
# 8         8   12  20238.833333  11452.166667
# 9         9   11  31775.818182  16969.090909

# %% [markdown]
# ## 2. Вывести количество отправлений в разрезе индексов отделений, в которых было принято отправление. Учитывать только те отправления, у которых масса  больше  или равна 10 кг.

# %%
sql = '''
select t.index_id,
    count(t.index_id) as cnt
from parcel_aggr t
where t.mass >= 10000
group by t.index_id
'''

# %%
select(sql)
# Out:
#    index_id  cnt
# 0         0    4
# 1         1    7
# 2         2    9
# 3         3    3
# 4         4    6
# 5         5    3
# 6         6    7
# 7         7    9
# 8         8    7
# 9         9    8

# %%
sql = '''
select t.index_id,
    count(1) as cnt_all,
    count(case when t.mass >= 10000 then 1 else null end) as cnt_10kg,
    count(case when t.mass >= 10000 then 1 else null end) * 1.0 / count(1) as pct_10kg
from parcel_aggr t
group by t.index_id 
'''

# %%
select(sql)
# Out:
#    index_id  cnt_all  cnt_10kg  pct_10kg
# 0         0        7         4  0.571429
# 1         1       10         7  0.700000
# 2         2        9         9  1.000000
# 3         3        9         3  0.333333
# 4         4       10         6  0.600000
# 5         5        6         3  0.500000
# 6         6       11         7  0.636364
# 7         7       15         9  0.600000
# 8         8       12         7  0.583333
# 9         9       11         8  0.727273

# %% [markdown]
# ## 3. Вывести  количество отправлений в разрезе  типа отправителя и группы по численности населения населенного пункта, в котором было принято отправление (меньше 50 тыс. (включительно), от 50 до 100 тыс. (включительно), от 100 до 500 тыс. (включительно), больше 500 тыс.).

# %%
sql = '''
select t.client_type,

case when i.population <= 50000 then '1. до 50'
when i.population <= 100000 then '2. от 50 до 100'
when i.population <= 500000 then '3. от 100 до 500'
else '4. от 500' end as population_group,

i.population
from parcel_aggr t
left join index_data i on t.index_id = i.index_id
'''

# %%
select(sql)
# Out:
#          client_type  population_group  population
# 0    Физическое лицо  3. от 100 до 500      200000
# 1   Юридическое лицо   2. от 50 до 100       70000
# 2    Физическое лицо  3. от 100 до 500      300000
# 3    Физическое лицо  3. от 100 до 500      100001
# 4    Физическое лицо  3. от 100 до 500      200000
# ..               ...               ...         ...
# 95  Юридическое лицо         4. от 500      700000
# 96  Юридическое лицо         4. от 500      600000
# 97  Юридическое лицо  3. от 100 до 500      200000
# 98  Юридическое лицо         4. от 500      600000
# 99   Физическое лицо  3. от 100 до 500      300000
#
# [100 rows x 3 columns]

# %%
sql = '''
select t.client_type,

case when i.population <= 50000 then '1. до 50'
when i.population <= 100000 then '2. от 50 до 100'
when i.population <= 500000 then '3. от 100 до 500'
else '4. от 500' end as population_group,

count(1) as cnt

from parcel_aggr t
left join index_data i on t.index_id = i.index_id

group by t.client_type,
case when i.population <= 50000 then '1. до 50'
when i.population <= 100000 then '2. от 50 до 100'
when i.population <= 500000 then '3. от 100 до 500'
else '4. от 500' end

order by 1,2
'''

# %%
select(sql)
# Out:
#         client_type  population_group  cnt
# 0   Физическое лицо          1. до 50    9
# 1   Физическое лицо   2. от 50 до 100    9
# 2   Физическое лицо  3. от 100 до 500   22
# 3   Физическое лицо         4. от 500    4
# 4  Юридическое лицо          1. до 50    8
# 5  Юридическое лицо   2. от 50 до 100    9
# 6  Юридическое лицо  3. от 100 до 500   20
# 7  Юридическое лицо         4. от 500   19

# %% [markdown]
# ## 4. Вывести идентификатор отправления; регион, где было принято отправление; численность населения населенного пункта, в котором было принято отправление и стоимость пересылки отправления (в рублях) с максимальной массой в каждом филиале.

# %%
sql = '''
select t.parcel_id, t.area, t.population, t.price from

(select t.*, i.population, i.area,
    rank() over (partition by t.index_id order by t.mass desc) as rnk
from parcel_aggr t
left join index_data i on t.index_id = i.index_id) t

where t.rnk = 1
'''

# %%
select(sql)
# Out:
#    parcel_id area  population  price
# 0         91    a       10000  48746
# 1         64    b       20002  42501
# 2         31    c       60000  84091
# 3         47    d       70000  52285
# 4         73    e      100001  72586
# 5         14    f      150000  58997
# 6         37    g      200000  68387
# 7         74    h      300000  94790
# 8         79    i      600000  69503
# 9         65    j      700000  64250

# %% [markdown]
# ## 5. Вывести идентификаторы отправлений, у которых  масса строго больше, чем в среднем по базе.

# %%
sql = '''
select t.parcel_id
from parcel_aggr as t
where t.mass > (select avg(t.mass) as mass_avg from parcel_aggr t)
'''

# %%
select(sql)
# Out:
#     parcel_id
# 0           0
# 1           2
# 2           3
# 3           6
# 4           7
# 5           9
# 6          13
# 7          14
# 8          17
# 9          19
# 10         20
# 11         23
# 12         27
# 13         31
# 14         34
# 15         37
# 16         38
# 17         40
# 18         44
# 19         47
# 20         48
# 21         49
# 22         50
# 23         53
# 24         54
# 25         55
# 26         58
# 27         59
# 28         64
# 29         65
# 30         67
# 31         68
# 32         70
# 33         71
# 34         73
# 35         74
# 36         75
# 37         79
# 38         81
# 39         82
# 40         86
# 41         87
# 42         89
# 43         91
# 44         95
# 45         96
